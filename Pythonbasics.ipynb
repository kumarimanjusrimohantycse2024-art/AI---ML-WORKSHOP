# %% [markdown]
# #DAY 2

# %%
nsteps = int(input("Enter Number of steps to Move:"))
p = [0,0]
inc = 10
dir_ = 0
for i in range(nsteps):
    if dir_ == 0:
        p[0]  += inc
    elif dir_ == 1:
        p[1] += inc
    elif dir_ == 2:
        p[0] -= inc
    elif dir_ == 3:
        p[1] -= inc
        dir_ = -1
    inc+=10
    dir+=1
    print(p, inc, dir_, i)
